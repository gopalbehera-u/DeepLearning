# %%
from ultralytics import YOLO
import numpy

# %%
model=YOLO('yolov8n.pt','v8')

# %%
detect_output=model.predict(source=r'C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\yolo\imgs\1.jpg',save=True,conf=0.25)
print(detect_output)
# Out:
# image 1/1 C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\yolo\imgs\1.jpg: 352x640 3 persons, 2 bicycles, 4 cars, 1 bus, 3 traffic lights, 1 backpack, 192.6ms
# Speed: 14.0ms preprocess, 192.6ms inference, 25.6ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\yolo\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
