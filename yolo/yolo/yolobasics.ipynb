# %%
import sys

# !{sys.executable} -m pip install ultralytics --user
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.89-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (3.10.9)
# Collecting opencv-python!=4.13.0.90,>=4.6.0 (from ultralytics)
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.12.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.27.1)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\beher\appdata\roaming\python\python310\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.42.1)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\beher\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\beher\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.42.1 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from polars>=0.20.0->ultralytics) (1.42.1)
# Requirement already satisfied: six>=1.5 in c:\users\beher\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\beher\appdata\roaming\python\python310\site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (57.4.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\beher\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Using cached ultralytics-8.4.89-py3-none-any.whl (1.3 MB)
# Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
# Installing collected packages: opencv-python, ultralytics
#
#    ---------------------------------------- 0/2 [opencv-python]
#    ---------------------------------------- 0/2 [opencv-python]
#    ---------------------------------------- 0/2 [opencv-python]
#    ---------------------------------------- 0/2 [opencv-python]
#    ---------------------------------------- 0/2 [opencv-python]
#    ---------------------------------------- 0/2 [opencv-python]
#    ---------------------------------------- 0/2 [opencv-python]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    ---------------------------------------- 2/2 [ultralytics]
#
# Successfully installed opencv-python-5.0.0.93 ultralytics-8.4.89

# %%
from ultralytics import YOLO
import numpy

# %%
model=YOLO('yolov8n.pt','v8')

# %%
detect_output=model.predict(source=r'C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\yolo\imgs\1.jpg',save=True,conf=0.25)
print(detect_output)
# Out:
# image 1/1 C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\yolo\imgs\1.jpg: 352x640 3 persons, 2 bicycles, 4 cars, 1 bus, 3 traffic lights, 1 backpack, 52.2ms
# Speed: 3.5ms preprocess, 52.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\yolo\runs\detect\predict-9
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[  9,   2,   5],
#         [ 13,   6,   9],
#         [ 17,  10,  13],
#         ...,
#         [213, 208, 183],
#         [223, 218, 193],
#         [235, 230, 205]],
#
#        [[ 10,   3,   6],
#         [ 15,   8,  11],
#         [ 19,  12,  15],
#         ...,
#         [222, 220, 196],
#         [228, 224, 200],
#         [231, 229, 205]],
#
#        [[ 11,   4,   7],
#         [ 16,   9,  12],
#         [ 23,  14,  17],
#         ...,
#         [220, 222, 203],
#         [222, 222, 204],
#         [224, 226, 207]],
#
#        ...,
#
#        [[174, 186, 180],
#         [170, 182, 176],
#         [173, 185, 179],
#         ...,
#         [122, 123, 133],
#         [123, 124, 134],
#         [122, 123, 133]],
#
#        [[145, 157, 151],
#         [143, 155, 149],
#         [148, 160, 154],
#         ...,
#         [124, 125, 135],
#         [123, 124, 134],
#         [121, 122, 132]],
#
#        [[164, 176, 170],
#         [168, 180, 174],
#         [172, 184, 178],
#         ...,
#         [129, 130, 140],
#         [127, 128, 138],
#         [124, 125, 135]]], shape=(500, 960, 3), dtype=uint8)
# orig_shape: (500, 960)
# path: 'C:\\Users\\beher\\OneDrive\\Desktop\\DeepLearning\\yolo\\yolo\\imgs\\1.jpg'
# probs: None
# save_dir: 'C:\\Users\\beher\\OneDrive\\Desktop\\DeepLearning\\yolo\\yolo\\runs\\detect\\predict-9'
# semantic_mask: None
# speed: {'preprocess': 3.476599929854274, 'inference': 52.22179996781051, 'postprocess': 1.6947999829426408}]

# %%
import mediapipe as mp

# %%
import tensorflow as tf
import keras

print("TensorFlow Version:", tf.__version__)
print("Keras Version:", keras.__version__)
# Out:
# TensorFlow Version: 2.21.0
# Keras Version: 3.12.3

# %%
import cv2
