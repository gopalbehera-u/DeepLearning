# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.80  Python-3.13.5 torch-2.12.1+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Setup complete  (12 CPUs, 15.4 GB RAM, 287.3/475.2 GB disk)

# %%
from ultralytics import YOLO
model=YOLO("yolov8n.pt")
