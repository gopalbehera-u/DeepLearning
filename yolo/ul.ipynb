# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.4.80  Python-3.13.5 torch-2.12.1+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Setup complete  (12 CPUs, 15.4 GB RAM, 286.2/475.2 GB disk)

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')

# %%
# !yolo checks
# Out:
# Ultralytics 8.4.80  Python-3.13.5 torch-2.12.1+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Setup complete  (12 CPUs, 15.4 GB RAM, 286.2/475.2 GB disk)
#
# OS                     Windows-11-10.0.26200-SP0
# Environment            Windows
# Python                 3.13.5
# Install                pip
# Path                   C:\Users\beher\anaconda3\Lib\site-packages\ultralytics
# RAM                    15.41 GB
# Disk                   286.2/475.2 GB
# CPU                    AMD Ryzen 5 5600H with Radeon Graphics
# CPU count              12
# GPU                    None
# GPU count              None
# CUDA                   None
#
# numpy                   2.1.3>=1.23.0
# matplotlib              3.10.0>=3.3.0
# opencv-python           4.13.0.92>=4.6.0
# pillow                  11.1.0>=7.1.2
# pyyaml                  6.0.2>=5.3.1
# requests                2.32.3>=2.23.0
# torch                   2.12.1>=1.8.0
# ...

# %%
detect=model.predict(source=r'C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\ing.png',conf=0.25,save=True)
print(detect)
# Out:
# image 1/1 C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\ing.png: 448x640 5 persons, 2 cups, 4 chairs, 2 potted plants, 1 dining table, 1 laptop, 264.2ms
# Speed: 16.3ms preprocess, 264.2ms inference, 33.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\beher\OneDrive\Desktop\DeepLearning\yolo\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
