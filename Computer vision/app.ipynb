# %%
import cv2

# %%
input=cv2.imread(r'C:\Users\beher\OneDrive\Desktop\DeepLearning\cnn\happy\nani1.jpg')

# %%
input
# Out:
# array([[[ 72,  82, 136],
#         [ 72,  82, 136],
#         [ 72,  82, 136],
#         ...,
#         [ 50,  56,  75],
#         [ 50,  56,  75],
#         [ 51,  57,  76]],
#
#        [[ 72,  82, 136],
#         [ 72,  82, 136],
#         [ 72,  82, 136],
#         ...,
#         [ 50,  56,  75],
#         [ 50,  56,  75],
#         [ 50,  56,  75]],
#
#        [[ 73,  83, 137],
#         [ 73,  83, 137],
#         [ 71,  83, 137],
#         ...,
#         [ 49,  55,  74],
#         [ 49,  55,  74],
#         [ 49,  55,  74]],
#
#        ...,
#
#        [[ 65,  59,  54],
#         [ 65,  59,  54],
#         [ 65,  59,  54],
#         ...,
#         [ 52,  47,  44],
#         [ 53,  48,  45],
#         [ 53,  48,  45]],
#
#        [[ 65,  59,  54],
#         [ 65,  59,  54],
#         [ 65,  59,  54],
#         ...,
#         [ 50,  45,  42],
#         [ 50,  45,  42],
#         [ 50,  45,  42]],
#
#        [[ 64,  58,  53],
#         [ 64,  58,  53],
#         [ 64,  58,  53],
#         ...,
#         [ 50,  45,  42],
#         [ 49,  44,  41],
#         [ 48,  43,  40]]], dtype=uint8)

# %%
import numpy as np

# %%
cv2.imshow('Nani',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print("Height",int(input.shape[0]),'pixels')
print("width",int(input.shape[1]),'pixels')
# Out:
# Height 960 pixels
# width 768 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\beher\\OneDrive\\Desktop\\DeepLearning\\Computer vision'
